# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image = cv2.imread("resources/Brush/image_0.png")
#img_copy = img.copy()
img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# plt.figure(figsize=())

plt.subplot(1, 2, 1)
plt.imshow(image)
plt.subplot(1, 2, 2)
plt.imshow(image, "gray")
